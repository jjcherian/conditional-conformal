# %%
import numpy as np

rng = np.random.default_rng(seed=0)

n = int(1e6)
num_trials = int(1e3)
samples = rng.uniform(0, 1, size=(int(n), num_trials))

1 / np.sum(samples > 1 - (3/(2*(n))), axis=0)
# Out:
# /var/folders/2c/q6mwmmzj2ql08r9nph0mbnwr0000gn/T/ipykernel_91823/307735601.py:9: RuntimeWarning: divide by zero encountered in divide
#   1 / np.sum(samples > 1 - (3/(2*(n))), axis=0)
# array([0.33333333,        inf, 0.5       , 1.        , 0.33333333,
#        0.5       ,        inf, 0.25      , 1.        , 1.        ,
#               inf, 0.5       , 0.33333333, 0.2       , 1.        ,
#        1.        , 0.5       , 1.        , 1.        , 1.        ,
#        1.        , 1.        ,        inf, 0.33333333, 0.5       ,
#        0.25      , 0.33333333, 0.25      , 1.        , 0.5       ,
#        0.5       , 1.        ,        inf, 1.        , 0.25      ,
#        0.5       ,        inf, 1.        , 0.25      , 1.        ,
#        1.        , 1.        ,        inf,        inf, 0.5       ,
#        1.        , 0.33333333, 0.5       , 1.        , 0.5       ,
#        1.        , 0.33333333,        inf, 1.        ,        inf,
# ...

# %%
results[results == np.inf] = 0

np.mean(results)
# Out:
# 0.5128833333333334
